# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # read dataset

# %%
os.chdir('C:\\Users\\7ouda\\Desktop\\lecturs_epsilon')

# %%
pwd
# Out:
# 'C:\\Users\\7ouda\\Desktop\\lecturs_epsilon'

# %%
data = pd.read_csv('data_2/bikes.csv')

# %% [markdown]
# # show dataset

# %%
data
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
data.shape
# Out:
# (10886, 11)

# %% [markdown]
# # check null values

# %%
data.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                856
# workingday            1498
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# dtype: int64

# %% [markdown]
# # information about dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %% [markdown]
# # know the ( mean , std , count ,min , max , Q1 , Q2 ,Q3)

# %%
data.describe().transpose()
# Out:
#                       count        mean         std   min      25%      50%  \
# holiday             10030.0    0.029113    0.168131  0.00   0.0000    0.000
# workingday           9388.0    0.678206    0.467189  0.00   0.0000    1.000
# temp                 8104.0   20.317665    7.818568  0.82  13.9400   20.500
# humidity             7462.0   61.790673   19.262084  0.00  47.0000   62.000
# windspeed            6820.0   12.708806    8.131154  0.00   7.0015   12.998
# casual              10886.0   36.021955   49.960477  0.00   4.0000   17.000
# registered          10886.0  155.552177  151.039033  0.00  36.0000  118.000
# rented_bikes_count  10886.0  191.574132  181.144454  1.00  42.0000  145.000
#
#                          75%       max
# holiday               0.0000    1.0000
# workingday            1.0000    1.0000
# temp                 26.2400   41.0000
# humidity             77.0000  100.0000
# windspeed            16.9979   56.9969
# casual               49.0000  367.0000
# ...

# %% [markdown]
# # Know the vareans

# %%
data.var()
# Out:
# C:\Users\7ouda\AppData\Local\Temp/ipykernel_12380/445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# holiday                   0.028268
# workingday                0.218266
# temp                     61.130007
# humidity                371.027882
# windspeed                66.115669
# casual                 2496.049219
# registered            22812.789514
# rented_bikes_count    32813.313153
# dtype: float64

# %% [markdown]
# # 1- Make Profit Feature

# %%
data['Profit']=data['registered'] * 5 + data['casual']*20  + 0.14 + 4.21

# %% [markdown]
# # 2-  Distribution rental_bikes_count & profit.

# %%
data[['rented_bikes_count','Profit']].describe()
# Out:
#        rented_bikes_count        Profit
# count        10886.000000  10886.000000
# mean           191.574132   1502.549982
# std            181.144454   1522.887674
# min              1.000000      9.350000
# 25%             42.000000    299.350000
# 50%            145.000000   1039.350000
# 75%            284.000000   2204.350000
# max            977.000000   9169.350000

# %% [markdown]
# # 3- Profit for each day.

# %%
data["days_name"]= pd.to_datetime(data["datetime"])

# %%
data['dates'] = data['days_name'].dt.day_name()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
#  11  Profit              10886 non-null  float64
#  12  days_name           10886 non-null  datetime64[ns]
#  13  dates               10886 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(4)
# ...

# %%
data.groupby('dates')['Profit'].sum()
# Out:
# dates
# Friday       2230201.15
# Monday       2177546.85
# Saturday     3076210.40
# Sunday       2785858.65
# Thursday     2098005.55
# Tuesday      1997094.65
# Wednesday    1991841.85
# Name: Profit, dtype: float64

# %% [markdown]
# # 4- Which season that has more registration & profit

# %%
data.groupby('season')['registered','Profit'].agg(['max'])
# Out:
# C:\Users\7ouda\AppData\Local\Temp/ipykernel_12380/1257620843.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('season')['registered','Profit'].agg(['max'])
#        registered   Profit
#               max      max
# season
# Fall          886  9169.35
# Spring        681  8934.35
# Summer        782  9069.35
# Winter        857  9149.35

# %%
data.groupby('season').agg({'registered':['max'],'Profit':['max']})
# Out:
#        registered   Profit
#               max      max
# season
# Fall          886  9169.35
# Spring        681  8934.35
# Summer        782  9069.35
# Winter        857  9149.35

# %% [markdown]
# # 5-Which weather condition that has more registration & profit

# %%
data.groupby('weather')['registered','Profit'].agg(['max'])
# Out:
# C:\Users\7ouda\AppData\Local\Temp/ipykernel_12380/1809491073.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('weather')['registered','Profit'].agg(['max'])
#         registered   Profit
#                max      max
# weather
# Clear          886  9069.35
# Mist           788  9169.35
# Rainy          791  6449.35
# Snowy          158   914.35

# %%
data.groupby('weather').agg({'registered':['max'],'Profit':['max']})
# Out:
#         registered   Profit
#                max      max
# weather
# Clear          886  9069.35
# Mist           788  9169.35
# Rainy          791  6449.35
# Snowy          158   914.35

# %% [markdown]
# # 6- Correlation between profit & bikes count with all features

# %%
data.groupby(['Profit','rented_bikes_count']).corr()
# Out:
#                                        holiday  workingday      temp  \
# Profit  rented_bikes_count
# 9.35    1                  holiday         NaN         NaN       NaN
#                            workingday      NaN    1.000000  0.229215
#                            temp            NaN    0.229215  1.000000
#                            humidity        NaN    0.049723  0.295959
#                            windspeed       NaN    0.153883  0.113179
# ...                                        ...         ...       ...
# 9169.35 783                temp            NaN         NaN       NaN
#                            humidity        NaN         NaN       NaN
#                            windspeed       NaN         NaN       NaN
#                            casual          NaN         NaN       NaN
#                            registered      NaN         NaN       NaN
#
#                                        humidity  windspeed  casual  registered
# Profit  rented_bikes_count
# ...

# %% [markdown]
# # 7-  Rentals during rush hours (7-9 am & 3-5 pm)

# %%
data[(data['datetime'] >= '2011-01-01 07:00:00' )& (data['datetime'] >= '2011-01-01 07:00:00'  )]
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 7      2011-01-01 07:00:00  Spring      0.0         0.0   Clear   8.20
# 8      2011-01-01 08:00:00  Spring      0.0         0.0     NaN   9.84
# 9      2011-01-01 09:00:00  Spring      0.0         0.0   Clear    NaN
# 10     2011-01-01 10:00:00  Spring      0.0         0.0   Clear  15.58
# 11     2011-01-01 11:00:00  Spring      NaN         0.0   Clear  14.76
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count   Profit  \
# ...

# %%
data[(data['datetime'] >= '2011-01-01 15:00:00' )& (data['datetime'] >= '2011-01-01 17:00:00'  )]
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 17     2011-01-01 17:00:00  Spring      NaN         NaN    Mist  18.04
# 18     2011-01-01 18:00:00  Spring      NaN         0.0   Rainy  17.22
# 19     2011-01-01 19:00:00  Spring      0.0         0.0   Rainy  17.22
# 20     2011-01-01 20:00:00  Spring      0.0         0.0    Mist  16.40
# 21     2011-01-01 21:00:00  Spring      0.0         0.0    Mist    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count   Profit  \
# ...

# %% [markdown]
# # 8-  Rentals during workday & holiday.

# %%
data[(data['holiday'] == 1)]['rented_bikes_count'].agg(['count'])
# Out:
# count    292
# Name: rented_bikes_count, dtype: int64

# %%
data[(data['workingday'] == 1)]['rented_bikes_count'].agg(['count'])
# Out:
# count    6367
# Name: rented_bikes_count, dtype: int64

# %% [markdown]
# # 9- Registered or casual is more.

# %%
data['registered'].sum()
# Out:
# 1693341

# %%
data['casual'].sum()
# Out:
# 392135

# %% [markdown]
# # 10- What is the average of bikes would be registered during the week.

# %%
data.groupby('weather')['registered'].sum() / 13
# Out:
# weather
# Clear    73188.384615
# Mist     25863.769231
# Rainy     5400.307692
# Snowy       12.153846
# Name: registered, dtype: float64

# %% [markdown]
# # 11- Schools (9-12) & (2-6) profit

# %%
data['datetime'] = pd.to_datetime(data['datetime'])

# %%
data['Date'], data['Time'] = data['datetime'].dt.normalize() , data['datetime'].dt.time

# %%
data
# Out:
#                  datetime  season  holiday  workingday weather   temp  \
# 0     2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1     2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2     2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3     2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4     2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                   ...     ...      ...         ...     ...    ...
# 10881 2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882 2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883 2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884 2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885 2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count   Profit  \
# ...

# %%
data[(data['datetime'] >= '2011-09-01 00:00:00' )& (data['datetime'] <= '2011-12-01 00:00:00'  )]['Profit'].sum()
# Out:
# 1838002.7500000002

# %%
data[(data['datetime'] >= '2011-02-01 00:00:00' )& (data['datetime'] <= '2011-06-01 00:00:00'  )]['Profit'].sum()
# Out:
# 1613897.4000000001

# %% [markdown]
# # 12- Profit in 2011 & Saturdays & season fall

# %%
data[((data['datetime'] >= '2011-01-01 00:00:00' )
      & (data['datetime'] <= '2011-12-30 00:00:00'  )
      & (data['datetime'].dt.day_name() == 'Saturday')
      & (data['season'] == 'Fall'))]['Profit'].sum()
# Out:
# 409798.44999999995

# %% [markdown]
# # great worke finally
